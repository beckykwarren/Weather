# %%
# Dependencies
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd

from citipy import citipy
from datetime import datetime
from config import api_key

# %%
#13 thousand cities from:
#https://simplemaps.com/data/world-cities

cities_df = pd.read_csv("worldcities.csv")
cities_df.head()
# Out:
#           city   city_ascii      lat      lng country iso2 iso3   admin_name  \
# 0    Malishevë    Malisheve  42.4822  20.7458  Kosovo   XK  XKS    Malishevë
# 1      Prizren      Prizren  42.2139  20.7397  Kosovo   XK  XKS      Prizren
# 2  Zubin Potok  Zubin Potok  42.9144  20.6897  Kosovo   XK  XKS  Zubin Potok
# 3     Kamenicë     Kamenice  42.5781  21.5803  Kosovo   XK  XKS     Kamenicë
# 4         Viti         Viti  42.3214  21.3583  Kosovo   XK  XKS         Viti
#
#   capital  population          id
# 0   admin         NaN  1901597212
# 1   admin         NaN  1901360309
# 2   admin         NaN  1901608808
# 3   admin         NaN  1901851592
# 4   admin         NaN  1901328795

# %%
# choose a random number to stratify the sample
import random
r =  random.randint(0,10)
r
# Out:
# 9

# %%
# stratify the city list to return 600 cities
rand_cities = []
coordinates = []

for i in range(600):
    
    j=i*20+r
    
    rand_cities.append(cities_df.iloc[j,0])
    lat = cities_df.iloc[j,2]
    lon = cities_df.iloc[j,3]
    coordinates.append((lat,lon))

#print(rand_cities)

# %%
# information for open weather
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
#response = requests.get(query_url + "London").json()
#response

# %%
# set up lists to hold reponse info
lat = []
temp = []
name = []
humid = []
wind = []
clouds = []
i = 1

# Set date for API call
todays_date = datetime.now()
date_of_api = todays_date.strftime("%d %b %Y")
date_of_api


# Loop through the list of cities and perform a request for data on each
for city in rand_cities:
    print(f"Finding record number {i}: {city}")
    try:        
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        name.append(city)
        humid.append(response['main']['humidity'])
        wind.append(response['wind']['speed'])
        clouds.append(response['clouds']['all'])
    except:
        print(f"City not found...")
    i = i+1
# Out:
# Finding record number 1: Podujevë
# City not found...
# Finding record number 2: Ferizaj
# City not found...
# Finding record number 3: Dhamar
# Finding record number 4: Rustenburg
# Finding record number 5: Vanhynsdorp
# City not found...
# Finding record number 6: Colesberg
# Finding record number 7: Ladysmith
# Finding record number 8: Mufulira
# Finding record number 9: Chinsali
# Finding record number 10: Masvingo
# Finding record number 11: Shemonaikha
# Finding record number 12: Shieli
# Finding record number 13: Qaraghandy
# Finding record number 14: Temirtau
# Finding record number 15: Shymkent
# Finding record number 16: Champasak
# Finding record number 17: Schellenberg
# Finding record number 18: Tubmanburg
# Finding record number 19: Mohales Hoek
# Finding record number 20: Kupiškis
# Finding record number 21: Panevežys
# City not found...
# Finding record number 22: Mersch
# Finding record number 23: Ādaži
# Finding record number 24: Limbaži
# Finding record number 25: Balvi
# Finding record number 26: Baldone
# Finding record number 27: Rucava
# Finding record number 28: Ozolnieki
# Finding record number 29: Darnah
# Finding record number 30: Kenitra
# Finding record number 31: Ouezzane
# City not found...
# Finding record number 32: Briceni
# Finding record number 33: Berane
# Finding record number 34: Tivat
# Finding record number 35: Fianarantsoa
# Finding record number 36: Zrnovci
# Finding record number 37: Čučer-Sandevo
# City not found...
# Finding record number 38: Probištip
# City not found...
# Finding record number 39: Gevgelija
# Finding record number 40: Kita
# Finding record number 41: Labutta
# City not found...
# Finding record number 42: Shwebo
# Finding record number 43: Altay
# Finding record number 44: Fort-de-France
# Finding record number 45: Tevragh Zeina
# City not found...
# Finding record number 46: Żurrieq
# Finding record number 47: Xewkija
# Finding record number 48: Santa Venera
# Finding record number 49: Kulhudhuffushi
# Finding record number 50: Zomba
# Finding record number 51: Lilongwe
# Finding record number 52: Chihuahua
# Finding record number 53: Guerrero Negro
# Finding record number 54: Juchitan
# City not found...
# Finding record number 55: Orizaba
# Finding record number 56: Tuxpam
# City not found...
# Finding record number 57: Nezahualcoyotl
# City not found...
# Finding record number 58: Ciudad Valles
# Finding record number 59: Juan Aldama
# Finding record number 60: Huatabampo
# Finding record number 61: Kangar
# Finding record number 62: Seremban
# Finding record number 63: Macia
# Finding record number 64: Ongwediva
# Finding record number 65: Opuwo
# Finding record number 66: Tahoua
# Finding record number 67: Kontagora
# Finding record number 68: Ogbomosho
# Finding record number 69: Onitsha
# Finding record number 70: Birnin Kebbi
# Finding record number 71: Maastricht
# Finding record number 72: Bærum
# Finding record number 73: Gjøvik
# Finding record number 74: Lalitpur
# Finding record number 75: Nelson
# Finding record number 76: Kerikeri
# Finding record number 77: Haymā’
# City not found...
# Finding record number 78: Unión Chocó
# Finding record number 79: Motupe
# Finding record number 80: Ilo
# Finding record number 81: Huánuco
# Finding record number 82: Huancavelica
# Finding record number 83: Port Moresby
# Finding record number 84: Wabag
# Finding record number 85: Baler
# Finding record number 86: Caloocan City
# Finding record number 87: Kalibo
# City not found...
# Finding record number 88: Olongapo
# Finding record number 89: Surigao
# Finding record number 90: Tagum
# Finding record number 91: Bahawalpur
# Finding record number 92: Okara
# Finding record number 93: Inowrocław
# Finding record number 94: Aveiro
# Finding record number 95: Mariscal Estigarribia
# Finding record number 96: San Pedro
# Finding record number 97: Doha
# Finding record number 98: Buzău
# Finding record number 99: Târgoviște
# Finding record number 100: Kučevo
# City not found...
# Finding record number 101: Rekovac
# Finding record number 102: Titel
# Finding record number 103: Kovačica
# Finding record number 104: Novi Pazar
# Finding record number 105: Bela Crkva
# Finding record number 106: Dimitrovgrad
# Finding record number 107: Novy Urengoy
# Finding record number 108: Kolomna
# Finding record number 109: Chernogorsk
# Finding record number 110: Toguchin
# Finding record number 111: Bagdarin
# Finding record number 112: Tashtagol
# Finding record number 113: Barabinsk
# Finding record number 114: Starsy Oskol
# City not found...
# Finding record number 115: Tavda
# Finding record number 116: Plast
# Finding record number 117: Nizhnekamsk
# Finding record number 118: Kirovo-Chepetsk
# Finding record number 119: Kirsanov
# Finding record number 120: Penza
# Finding record number 121: Voronezh
# Finding record number 122: Novosibirsk
# Finding record number 123: Bataysk
# Finding record number 124: Bratsk
# Finding record number 125: Teli
# Finding record number 126: Zvezdnyy
# Finding record number 127: Noginsk
# Finding record number 128: Omchak
# City not found...
# Finding record number 129: Bilibino
# Finding record number 130: Kartaly
# Finding record number 131: Srednekolymsk
# Finding record number 132: Nikolayevsk na Amure
# City not found...
# Finding record number 133: Batagay
# Finding record number 134: Chelyabinsk
# Finding record number 135: Kaspiysk
# Finding record number 136: Al Kharj
# Finding record number 137: Al Mubarraz
# Finding record number 138: Ed Dueim
# Finding record number 139: El Obeid
# Finding record number 140: Kalmar
# Finding record number 141: Borås
# Finding record number 142: Volčja Draga
# Finding record number 143: Benedikt v Slovenskih Goricah
# Finding record number 144: Črenšovci
# Finding record number 145: Spodnje Hoče
# Finding record number 146: Kobilje
# Finding record number 147: Nova Gorica
# Finding record number 148: Radovljica
# Finding record number 149: Slovenske Konjice
# Finding record number 150: Makole
# Finding record number 151: Vransko
# Finding record number 152: Ankaran
# Finding record number 153: Louga
# Finding record number 154: Laascaanood
# Finding record number 155: Caluula
# Finding record number 156: Torit
# City not found...
# Finding record number 157: San Salvador
# Finding record number 158: Dar'a
# City not found...
# Finding record number 159: Nhlangano
# Finding record number 160: Mongo
# Finding record number 161: Sotouboua
# Finding record number 162: Phuket
# Finding record number 163: Trang
# Finding record number 164: Ratchaburi
# Finding record number 165: Kamphaeng Phet
# Finding record number 166: Lospalos
# Finding record number 167: Dehibat
# City not found...
# Finding record number 168: Medenine
# Finding record number 169: Bitlis
# Finding record number 170: Burdur
# Finding record number 171: İzmit
# Finding record number 172: Bayburt
# Finding record number 173: Port-of-Spain
# Finding record number 174: Hualien
# Finding record number 175: Kaohsiung
# Finding record number 176: Kasulu
# Finding record number 177: Tukuyu
# Finding record number 178: Bariadi
# Finding record number 179: Ternopil
# Finding record number 180: Rivne
# Finding record number 181: Kumi
# Finding record number 182: Kaabong
# Finding record number 183: Abim
# Finding record number 184: Kitamilo
# Finding record number 185: Kiryandongo
# Finding record number 186: Gombe
# Finding record number 187: Serere
# Finding record number 188: Maldonado
# Finding record number 189: Fargona
# Finding record number 190: Termiz
# Finding record number 191: Maracay
# Finding record number 192: Guasdualito
# Finding record number 193: Vung Tau
# Finding record number 194: Cẩm Phả
# City not found...
# Finding record number 195: Hon Quan
# City not found...
# Finding record number 196: Phủ Lý
# Finding record number 197: Apia
# Finding record number 198: Dubai
# Finding record number 199: Meymaneh
# City not found...
# Finding record number 200: Balkh
# Finding record number 201: Lushnjë
# Finding record number 202: Yeghegnadzor
# Finding record number 203: Ondjiva
# Finding record number 204: Sumbe
# Finding record number 205: Ushuaia
# Finding record number 206: Posadas
# Finding record number 207: San Luis
# Finding record number 208: Pampa del Infierno
# Finding record number 209: San Rafael
# Finding record number 210: Concepción del Uruguay
# Finding record number 211: Pergamino
# Finding record number 212: Tandil
# Finding record number 213: Klagenfurt
# Finding record number 214: Esperance
# Finding record number 215: Katanning
# Finding record number 216: Tom Price
# Finding record number 217: Broome
# Finding record number 218: Ceduna
# Finding record number 219: Orange
# Finding record number 220: Warwick
# Finding record number 221: Horsham
# Finding record number 222: Thargomindah
# Finding record number 223: Grafton
# Finding record number 224: Oranjestad
# Finding record number 225: Xaçmaz
# Finding record number 226: Lerik
# Finding record number 227: Qəbələ
# Finding record number 228: Mostar
# Finding record number 229: Arlon
# Finding record number 230: Sapouy
# Finding record number 231: Koupéla
# Finding record number 232: Stara Zagora
# Finding record number 233: Kirundo
# Finding record number 234: Cotonou
# Finding record number 235: Viacha
# Finding record number 236: Camargo
# Finding record number 237: Villa Martin
# Finding record number 238: Santo Ângelo
# Finding record number 239: Maringá
# Finding record number 240: Araranguá
# Finding record number 241: Guaira
# Finding record number 242: Jardim
# Finding record number 243: São Francisco do Sul
# Finding record number 244: Codó
# Finding record number 245: Óbidos
# Finding record number 246: Poços de Caldas
# Finding record number 247: Barreiros
# Finding record number 248: Senhor do Bonfim
# Finding record number 249: Itambé
# Finding record number 250: Nova Cruz
# Finding record number 251: Guanhães
# Finding record number 252: Caratinga
# Finding record number 253: Viseu
# Finding record number 254: Macaé
# Finding record number 255: Novo Horizonte
# Finding record number 256: Porto Santana
# City not found...
# Finding record number 257: Petrópolis
# Finding record number 258: Samtse
# Finding record number 259: Sowa Town
# City not found...
# Finding record number 260: Homyel
# Finding record number 261: Wetaskiwin
# Finding record number 262: Timmins
# Finding record number 263: St. John's
# City not found...
# Finding record number 264: Medicine Hat
# Finding record number 265: Holman
# Finding record number 266: North Battleford
# Finding record number 267: Cap-Chat
# Finding record number 268: Baddeck
# Finding record number 269: Ottawa
# Finding record number 270: Peterborough
# Finding record number 271: Bathurst
# Finding record number 272: Liverpool
# Finding record number 273: Kimpese
# Finding record number 274: Kinshasa
# Finding record number 275: Binga
# Finding record number 276: Mushie
# Finding record number 277: Kabinda
# Finding record number 278: Yakossi
# City not found...
# Finding record number 279: Gamboma
# Finding record number 280: Schwyz
# Finding record number 281: Soubré
# Finding record number 282: Sassandra
# Finding record number 283: Toltén
# City not found...
# Finding record number 284: Copiapó
# Finding record number 285: San Bernardo
# Finding record number 286: Puerto Natales
# Finding record number 287: Meiganga
# Finding record number 288: Foumban
# Finding record number 289: Shangqiu
# Finding record number 290: Lhasa
# Finding record number 291: Minxian
# City not found...
# Finding record number 292: Dali
# Finding record number 293: Dingzhou
# Finding record number 294: Shaoyang
# Finding record number 295: Putian
# Finding record number 296: Pingdingshan
# Finding record number 297: Yichang
# Finding record number 298: Xigaze
# City not found...
# Finding record number 299: Chamdo
# City not found...
# Finding record number 300: Yakeshi
# Finding record number 301: Jiamusi
# Finding record number 302: Zhangye
# Finding record number 303: Liaocheng
# Finding record number 304: Xinxiang
# Finding record number 305: Hefei
# Finding record number 306: Nanjing
# Finding record number 307: Siping
# Finding record number 308: Sincelejo
# Finding record number 309: Mocoa
# Finding record number 310: Bello
# Finding record number 311: Girardot
# Finding record number 312: Puerto Limon
# Finding record number 313: Holguín
# Finding record number 314: São Filipe
# Finding record number 315: Usti Nad Labem
# Finding record number 316: Bremen
# Finding record number 317: Wuppertal
# Finding record number 318: Nürnberg
# Finding record number 319: Viborg
# Finding record number 320: Moca
# Finding record number 321: San Pedro de Macorís
# Finding record number 322: Tamanrasset
# Finding record number 323: El Bayadh
# Finding record number 324: Tizi-Ouzou
# City not found...
# Finding record number 325: Sangolquí
# City not found...
# Finding record number 326: Latacunga
# Finding record number 327: Berenice
# City not found...
# Finding record number 328: Girga
# Finding record number 329: Kafr el Sheikh
# City not found...
# Finding record number 330: Zaragoza
# Finding record number 331: Salamanca
# Finding record number 332: Aksum
# Finding record number 333: Debre Markos
# Finding record number 334: Mikkeli
# Finding record number 335: Nandi
# Finding record number 336: Hvannasund
# City not found...
# Finding record number 337: Aix-en-Provence
# Finding record number 338: Vichy
# Finding record number 339: Melun
# Finding record number 340: Ndende
# City not found...
# Finding record number 341: Oxford
# Finding record number 342: Elgin
# Finding record number 343: Grimsby
# Finding record number 344: Bromley
# Finding record number 345: Maidenhead
# Finding record number 346: Hamilton
# Finding record number 347: Conwy
# Finding record number 348: Livingston
# Finding record number 349: Oakham
# Finding record number 350: York
# Finding record number 351: Newcastle
# Finding record number 352: Belfast
# Finding record number 353: Kourou
# Finding record number 354: Winneba
# Finding record number 355: Qasigiannguit
# Finding record number 356: Mamou
# Finding record number 357: Dabola
# Finding record number 358: Tripoli
# Finding record number 359: Chalkida
# Finding record number 360: Chimaltenango
# Finding record number 361: Catió
# Finding record number 362: La Ceiba
# Finding record number 363: Virovitica
# Finding record number 364: Cap-Haïtien
# Finding record number 365: Debrecen
# Finding record number 366: Kediri
# Finding record number 367: Baubau
# City not found...
# Finding record number 368: Tanjungpandan
# Finding record number 369: Kualakapuas
# Finding record number 370: Kendari
# Finding record number 371: Sligo
# Finding record number 372: Dublin
# Finding record number 373: Douglas
# Finding record number 374: Bidar
# Finding record number 375: Sangli
# Finding record number 376: Lucknow
# Finding record number 377: Kolhapur
# Finding record number 378: Khammam
# Finding record number 379: Amravati
# Finding record number 380: Aligarh
# Finding record number 381: Malegaon
# Finding record number 382: Mysore
# Finding record number 383: Alappuzha
# City not found...
# Finding record number 384: Tikrit
# Finding record number 385: Bojnurd
# Finding record number 386: Shiraz
# Finding record number 387: Bam
# Finding record number 388: Neyshabur
# Finding record number 389: Campobasso
# Finding record number 390: Modena
# Finding record number 391: Vibo Valentia
# Finding record number 392: Port Maria
# Finding record number 393: Tottori
# Finding record number 394: Kanoya
# Finding record number 395: Mito
# Finding record number 396: Utsunomiya
# Finding record number 397: Nakuru
# Finding record number 398: Machakos
# Finding record number 399: Karungu
# Finding record number 400: Jalal Abad
# City not found...
# Finding record number 401: Kampong Spoe
# Finding record number 402: Chongju
# Finding record number 403: Haeju
# Finding record number 404: Daejeon
# Finding record number 405: Kuwait
# Finding record number 406: Quincy
# Finding record number 407: Mattawa
# Finding record number 408: Othello
# Finding record number 409: Sequim
# Finding record number 410: Newcastle
# Finding record number 411: Toppenish
# Finding record number 412: Radford
# Finding record number 413: Harrisonburg
# Finding record number 414: Williamsburg
# Finding record number 415: Middletown
# Finding record number 416: Burlington
# Finding record number 417: Hartland
# Finding record number 418: Union Grove
# Finding record number 419: Evansville
# Finding record number 420: Oregon
# Finding record number 421: Monroe
# Finding record number 422: Richfield
# Finding record number 423: Cedarburg
# Finding record number 424: Bridgeport
# Finding record number 425: Winter Springs
# Finding record number 426: Port Saint Lucie
# Finding record number 427: Bonita Springs
# Finding record number 428: Miami
# Finding record number 429: DeLand
# Finding record number 430: Coral Gables
# Finding record number 431: Rockledge
# Finding record number 432: Lauderdale Lakes
# Finding record number 433: Plant City
# Finding record number 434: Margate
# Finding record number 435: North Bay Village
# Finding record number 436: Jackson
# Finding record number 437: Laconia
# Finding record number 438: North Caldwell
# Finding record number 439: Clayton
# Finding record number 440: Elizabeth
# Finding record number 441: Oradell
# Finding record number 442: Absecon
# Finding record number 443: Florham Park
# Finding record number 444: Palmyra
# Finding record number 445: Caldwell
# Finding record number 446: Lindenwold
# Finding record number 447: Lovington
# Finding record number 448: Albuquerque
# Finding record number 449: Denver City
# Finding record number 450: Vidor
# Finding record number 451: Canyon
# Finding record number 452: Sinton
# Finding record number 453: Atlanta
# Finding record number 454: Kirby
# Finding record number 455: Port Isabel
# Finding record number 456: Leon Valley
# Finding record number 457: Gladewater
# Finding record number 458: Buda
# Finding record number 459: Littlefield
# Finding record number 460: Palmview
# Finding record number 461: Slaton
# Finding record number 462: Progreso
# Finding record number 463: Stafford
# Finding record number 464: Paris
# Finding record number 465: Groves
# Finding record number 466: Greenville
# Finding record number 467: Crowley
# Finding record number 468: Natchitoches
# Finding record number 469: Ville Platte
# Finding record number 470: Franklin
# Finding record number 471: Wesley Chapel
# Finding record number 472: Rolesville
# Finding record number 473: Rocky Mount
# Finding record number 474: Brevard
# Finding record number 475: Gastonia
# Finding record number 476: High Point
# Finding record number 477: Siler City
# Finding record number 478: Wayne
# Finding record number 479: Blair
# Finding record number 480: Oak Ridge
# Finding record number 481: Savannah
# Finding record number 482: Atoka
# Finding record number 483: Cleveland
# Finding record number 484: Dayton
# Finding record number 485: Williston Park
# Finding record number 486: Utica
# Finding record number 487: Queens
# Finding record number 488: Medina
# Finding record number 489: Elmira
# Finding record number 490: Watervliet
# Finding record number 491: Haverstraw
# Finding record number 492: Oneonta
# Finding record number 493: Binghamton
# Finding record number 494: Staten Island
# Finding record number 495: Lansdale
# Finding record number 496: Dunmore
# Finding record number 497: McKees Rocks
# Finding record number 498: Erie
# Finding record number 499: Turtle Creek
# Finding record number 500: Reading
# Finding record number 501: Emmaus
# Finding record number 502: Allentown
# Finding record number 503: Bangor
# Finding record number 504: Milton
# Finding record number 505: Oakdale
# Finding record number 506: East Palo Alto
# Finding record number 507: Waterford
# Finding record number 508: Jackson
# Finding record number 509: Newman
# Finding record number 510: Fairfield
# Finding record number 511: Fort Bragg
# Finding record number 512: Holtville
# Finding record number 513: Reedley
# Finding record number 514: Fontana
# Finding record number 515: West Covina
# Finding record number 516: San Gabriel
# Finding record number 517: Escalon
# Finding record number 518: La Cañada Flintridge
# Finding record number 519: Moreno Valley
# Finding record number 520: Davis
# Finding record number 521: Garden Grove
# Finding record number 522: Gonzales
# Finding record number 523: Westminster
# Finding record number 524: La Mirada
# Finding record number 525: Corcoran
# Finding record number 526: Avenal
# Finding record number 527: Alamosa
# Finding record number 528: Manitou Springs
# Finding record number 529: Frederick
# Finding record number 530: Steamboat Springs
# Finding record number 531: Brighton
# Finding record number 532: Bessemer
# Finding record number 533: Fairhope
# Finding record number 534: Enterprise
# Finding record number 535: Helena
# Finding record number 536: Daphne
# Finding record number 537: Clarksville
# Finding record number 538: Maumelle
# Finding record number 539: Alma
# Finding record number 540: Barre
# Finding record number 541: Lockport
# Finding record number 542: Evanston
# Finding record number 543: West Frankfort
# Finding record number 544: Crystal Lake
# Finding record number 545: Silvis
# Finding record number 546: Minooka
# Finding record number 547: Antioch
# Finding record number 548: Warrenville
# Finding record number 549: West Chicago
# Finding record number 550: Byron
# Finding record number 551: Loves Park
# Finding record number 552: Northbrook
# Finding record number 553: Lake Villa
# Finding record number 554: Villa Park
# Finding record number 555: Evergreen Park
# Finding record number 556: Round Lake Beach
# Finding record number 557: North Chicago
# Finding record number 558: Cochran
# Finding record number 559: Locust Grove
# Finding record number 560: Commerce
# Finding record number 561: Monroe
# Finding record number 562: Austell
# Finding record number 563: Griffin
# Finding record number 564: Eastman
# Finding record number 565: Jeffersonville
# Finding record number 566: Columbia City
# Finding record number 567: Winfield
# Finding record number 568: New Albany
# Finding record number 569: Berne
# Finding record number 570: Rushville
# Finding record number 571: Pleasant Hill
# Finding record number 572: Iowa City
# Finding record number 573: Decorah
# Finding record number 574: Cedar Falls
# Finding record number 575: Broken Arrow
# Finding record number 576: Clinton
# Finding record number 577: Ponca City
# Finding record number 578: Ada
# Finding record number 579: Eloy
# Finding record number 580: Yuma
# Finding record number 581: Florence
# Finding record number 582: Payette
# Finding record number 583: Emmett
# Finding record number 584: New Haven
# Finding record number 585: Portland
# Finding record number 586: Princess Anne
# Finding record number 587: College Park
# Finding record number 588: North Adams
# Finding record number 589: Lowell
# Finding record number 590: Monroe
# Finding record number 591: Miamisburg
# Finding record number 592: Warren
# Finding record number 593: Shelby
# Finding record number 594: Mount Healthy
# Finding record number 595: Barberton
# Finding record number 596: Bucyrus
# Finding record number 597: Hilliard
# Finding record number 598: Middleport
# Finding record number 599: Salem
# Finding record number 600: Green

# %%
# create a data frame from cities, lat, and temp etc


weather_dict = {
    "city": name,
    "lat": lat,
    "temp": temp,
    "humidity": humid,
    "wind speed": wind,
    "clouds": clouds
}


weather_data = pd.DataFrame(weather_dict)
weather_data.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>city</th>\n      <th>lat</th>\n      <th>temp</th>\n      <th>humidity</th>\n      <th>wind speed</th>\n      <th>clouds</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Dhamar</td>\n      <td>14.54</td>\n      <td>68.81</td>\n      <td>73</td>\n      <td>0.98</td>\n      <td>83</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Rustenburg</td>\n      <td>-25.67</td>\n      <td>75.29</td>\n      <td>23</td>\n      <td>3.00</td>\n      <td>76</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Colesberg</td>\n      <td>-30.72</td>\n      <td>57.47</td>\n      <td>28</td>\n      <td>12.06</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Ladysmith</td>\n      <td>-28.55</td>\n      <td>74.21</td>\n      <td>24</td>\n      <td>9.51</td>\n      <td>52</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Mufulira</td>\n      <td>-12.55</td>\n      <td>76.91</td>\n      <td>35</td>\n      <td>5.97</td>\n      <td>79</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Chinsali</td>\n      <td>-10.55</td>\n      <td>78.53</td>\n      <td>36</td>\n      <td>11.39</td>\n      <td>40</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Masvingo</td>\n      <td>-20.08</td>\n      <td>72.23</td>\n      <td>20</td>\n      <td>6.71</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>Shemonaikha</td>\n      <td>50.63</td>\n      <td>52.97</td>\n      <td>72</td>\n      <td>6.06</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>Shieli</td>\n      <td>44.18</td>\n      <td>65.75</td>\n      <td>44</td>\n      <td>3.74</td>\n      <td>77</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>Qaraghandy</td>\n      <td>49.80</td>\n      <td>41.00</td>\n      <td>60</td>\n      <td>6.71</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>Temirtau</td>\n      <td>50.05</td>\n      <td>41.00</td>\n      <td>60</td>\n      <td>6.71</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>Shymkent</td>\n      <td>42.31</td>\n      <td>59.00</td>\n      <td>54</td>\n      <td>6.71</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>Champasak</td>\n      <td>14.89</td>\n      <td>74.39</td>\n      <td>87</td>\n      <td>2.95</td>\n      <td>19</td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>Schellenberg</td>\n      <td>47.23</td>\n      <td>47.21</td>\n      <td>81</td>\n      <td>4.70</td>\n      <td>27</td>\n    </tr>\n    <tr>\n      <th>14</th>\n      <td>Tubmanburg</td>\n      <td>6.87</td>\n      <td>74.39</td>\n      <td>95</td>\n      <td>2.21</td>\n      <td>100</td>\n    </tr>\n    <tr>\n      <th>15</th>\n      <td>Mohales Hoek</td>\n      <td>-30.15</td>\n      <td>55.49</td>\n      <td>27</td>\n      <td>8.52</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>16</th>\n      <td>Kupiškis</td>\n      <td>55.84</td>\n      <td>36.41</td>\n      <td>85</td>\n      <td>5.25</td>\n      <td>99</td>\n    </tr>\n    <tr>\n      <th>17</th>\n      <td>Mersch</td>\n      <td>50.96</td>\n      <td>53.28</td>\n      <td>93</td>\n      <td>2.24</td>\n      <td>90</td>\n    </tr>\n    <tr>\n      <th>18</th>\n      <td>Ādaži</td>\n      <td>57.08</td>\n      <td>37.96</td>\n      <td>93</td>\n      <td>5.82</td>\n      <td>90</td>\n    </tr>\n    <tr>\n      <th>19</th>\n      <td>Limbaži</td>\n      <td>57.51</td>\n      <td>36.46</td>\n      <td>95</td>\n      <td>1.99</td>\n      <td>84</td>\n    </tr>\n    <tr>\n      <th>20</th>\n      <td>Balvi</td>\n      <td>57.13</td>\n      <td>32.63</td>\n      <td>88</td>\n      <td>2.91</td>\n      <td>96</td>\n    </tr>\n    <tr>\n      <th>21</th>\n      <td>Baldone</td>\n      <td>56.74</td>\n      <td>37.90</td>\n      <td>93</td>\n      <td>5.82</td>\n      <td>90</td>\n    </tr>\n    <tr>\n      <th>22</th>\n   ...

# %%
bob = weather_data.to_html()
bob.lstrip()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>city</th>\n      <th>lat</th>\n      <th>temp</th>\n      <th>humidity</th>\n      <th>wind speed</th>\n      <th>clouds</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Dhamar</td>\n      <td>14.54</td>\n      <td>68.81</td>\n      <td>73</td>\n      <td>0.98</td>\n      <td>83</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Rustenburg</td>\n      <td>-25.67</td>\n      <td>75.29</td>\n      <td>23</td>\n      <td>3.00</td>\n      <td>76</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Colesberg</td>\n      <td>-30.72</td>\n      <td>57.47</td>\n      <td>28</td>\n      <td>12.06</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Ladysmith</td>\n      <td>-28.55</td>\n      <td>74.21</td>\n      <td>24</td>\n      <td>9.51</td>\n      <td>52</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Mufulira</td>\n      <td>-12.55</td>\n      <td>76.91</td>\n      <td>35</td>\n      <td>5.97</td>\n      <td>79</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Chinsali</td>\n      <td>-10.55</td>\n      <td>78.53</td>\n      <td>36</td>\n      <td>11.39</td>\n      <td>40</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Masvingo</td>\n      <td>-20.08</td>\n      <td>72.23</td>\n      <td>20</td>\n      <td>6.71</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>Shemonaikha</td>\n      <td>50.63</td>\n      <td>52.97</td>\n      <td>72</td>\n      <td>6.06</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>Shieli</td>\n      <td>44.18</td>\n      <td>65.75</td>\n      <td>44</td>\n      <td>3.74</td>\n      <td>77</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>Qaraghandy</td>\n      <td>49.80</td>\n      <td>41.00</td>\n      <td>60</td>\n      <td>6.71</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>Temirtau</td>\n      <td>50.05</td>\n      <td>41.00</td>\n      <td>60</td>\n      <td>6.71</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>Shymkent</td>\n      <td>42.31</td>\n      <td>59.00</td>\n      <td>54</td>\n      <td>6.71</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>Champasak</td>\n      <td>14.89</td>\n      <td>74.39</td>\n      <td>87</td>\n      <td>2.95</td>\n      <td>19</td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>Schellenberg</td>\n      <td>47.23</td>\n      <td>47.21</td>\n      <td>81</td>\n      <td>4.70</td>\n      <td>27</td>\n    </tr>\n    <tr>\n      <th>14</th>\n      <td>Tubmanburg</td>\n      <td>6.87</td>\n      <td>74.39</td>\n      <td>95</td>\n      <td>2.21</td>\n      <td>100</td>\n    </tr>\n    <tr>\n      <th>15</th>\n      <td>Mohales Hoek</td>\n      <td>-30.15</td>\n      <td>55.49</td>\n      <td>27</td>\n      <td>8.52</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>16</th>\n      <td>Kupiškis</td>\n      <td>55.84</td>\n      <td>36.41</td>\n      <td>85</td>\n      <td>5.25</td>\n      <td>99</td>\n    </tr>\n    <tr>\n      <th>17</th>\n      <td>Mersch</td>\n      <td>50.96</td>\n      <td>53.28</td>\n      <td>93</td>\n      <td>2.24</td>\n      <td>90</td>\n    </tr>\n    <tr>\n      <th>18</th>\n      <td>Ādaži</td>\n      <td>57.08</td>\n      <td>37.96</td>\n      <td>93</td>\n      <td>5.82</td>\n      <td>90</td>\n    </tr>\n    <tr>\n      <th>19</th>\n      <td>Limbaži</td>\n      <td>57.51</td>\n      <td>36.46</td>\n      <td>95</td>\n      <td>1.99</td>\n      <td>84</td>\n    </tr>\n    <tr>\n      <th>20</th>\n      <td>Balvi</td>\n      <td>57.13</td>\n      <td>32.63</td>\n      <td>88</td>\n      <td>2.91</td>\n      <td>96</td>\n    </tr>\n    <tr>\n      <th>21</th>\n      <td>Baldone</td>\n      <td>56.74</td>\n      <td>37.90</td>\n      <td>93</td>\n      <td>5.82</td>\n      <td>90</td>\n    </tr>\n    <tr>\n      <th>22</th>\n   ...

# %%
#clean data
weather_data_clean = weather_data.loc[weather_data["humidity"]<=100]
high_wind = weather_data.loc[weather_data["wind speed"]>=30]
high_temp = weather_data.loc[weather_data["temp"]>=100]


print(high_wind)
print(high_temp)

weather_data_clean
# Out:
#        city    lat   temp  humidity  wind speed  clouds
# 551  Shelby  48.51  55.92        32       36.91       1
#        city    lat   temp  humidity  wind speed  clouds
# 446  Medina  24.47  100.4        11        2.24      40
#            city    lat   temp  humidity  wind speed  clouds
# 0        Dhamar  14.54  68.81        73        0.98      83
# 1    Rustenburg -25.67  75.29        23        3.00      76
# 2     Colesberg -30.72  57.47        28       12.06       0
# 3     Ladysmith -28.55  74.21        24        9.51      52
# 4      Mufulira -12.55  76.91        35        5.97      79
# ..          ...    ...    ...       ...         ...     ...
# 554     Bucyrus  40.81  60.96        59        3.36       1
# 555    Hilliard  40.03  59.54        72        4.70       1
# 556  Middleport  39.00  56.48       100        4.70      90
# 557       Salem  44.94  56.79        76        1.07       1
# 558       Green  40.95  59.72        77        4.70      90
#
# [559 rows x 6 columns]

# %%
# Build a scatter plot for humidity
plt.figure(figsize=(8,6))
plt.scatter(weather_data_clean["lat"], weather_data_clean["humidity"], marker=".", color = "#40798C")


# Incorporate the other graph properties
plt.title(f"Humidity in World Cities ({date_of_api})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("HumidityInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Humidity
#
# There isn't one clear trend with the humidity data however it is interesting to note that there is no city within 10 degrees of the equator that has humidity of less than 30%. There is a range of humidities at almost all latitudes though as you get above a latitude of 40 the humidity appears to increase.

# %%
# Build a scatter plot for temperature
plt.figure(figsize=(8,6))
plt.scatter(weather_data_clean["lat"], weather_data_clean["temp"], marker=".", color = "#40798C")

# Incorporate the other graph properties
plt.title(f"Temperature in World Cities ({date_of_api})")
plt.ylabel("Temperature (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Temperature
#
# From the scatter plot we can see that there is a clear trend of cooler temperatures towards the poles and warmer temeperatures towards the equator. There appears to be a skew towards the north. This may be due to the seasonal change. Though it is autumn in the northern hemisphere the temperatures often lag behind the astronomical seasons. The city with the highest temperature is Medina which has a latitude of 24.47 and the temperature was recorded as 104 F.

# %%
# Build a scatter plot for cloudiness
plt.figure(figsize=(8,6))
plt.scatter(weather_data_clean["lat"], weather_data_clean["clouds"], marker=".", color = "#40798C")

# Incorporate the other graph properties
plt.title(f"Cloudiness in World Cities {date_of_api})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Cloudiness
#
# The data appears to be clustered here however it is important to note that some of this is due to the measuring techniques. in some regions the cloudiness is measured in oktas or eighths of the sky. This means that some measurements are more likely for example the cluster at 87.5% and 75%. It is notable that there are very few places at the equator with zero cloud. Most places with zero cloud have a latitude of around -20 or between 20 and 60.

# %%
# Build a scatter plot for windspeed
plt.figure(figsize=(8,6))
plt.scatter(weather_data_clean["lat"], weather_data_clean["wind speed"], marker=".", color = "#40798C")

# Incorporate the other graph properties
plt.title(f"Wind Speed in World Cities ({date_of_api})")
plt.ylabel("Wind (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Wind Speed
#
# In the windspeed data there appears to be some outliers, notably Ushuaia which has a latitude of -54.81 and is considered to be the southern most city in the work. The windspeed is measures as 35.57 mph. This seems quite extreme however this may be expected due to the extreme location.
